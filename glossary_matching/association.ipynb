# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
import re, string

# %%
data=pd.read_csv('glossary_training_data2.csv')

# %%
data.head()
# Out:
#                       glossary1              glossary2  is_related  \
# 0                   Postal Code  Postal Index numbers            1
# 1                   Postal Code               Zip Code           1
# 2                   Postal Code              PIN code            1
# 3  Gender Identity / Expression     Sexual Orientation           1
# 4                  Credit Score            Credit Card           1
#
#    is_duplicate
# 0             1
# 1             1
# 2             1
# 3             0
# 4             0

# %%
data.shape
# Out:
# (816, 4)

# %%
def cleaned_text(text):
    clean = re.sub("\n"," ",text)
    clean=clean.lower()
    clean=re.sub(r"[~.,%/:;?_&+*=!-]"," ",clean)
    clean=re.sub("[^a-z]"," ",clean)
    clean=clean.lstrip()
    clean=clean.rstrip()
    clean=re.sub("\s{2,}"," ",clean)
    return clean
data["cleaned_glossary1"]=data["glossary1"].apply(cleaned_text)
data["cleaned_glossary2"]=data["glossary2"].apply(cleaned_text)
data.head()
# Out:
#                       glossary1              glossary2  is_related  \
# 0                   Postal Code  Postal Index numbers            1
# 1                   Postal Code               Zip Code           1
# 2                   Postal Code              PIN code            1
# 3  Gender Identity / Expression     Sexual Orientation           1
# 4                  Credit Score            Credit Card           1
#
#    is_duplicate           cleaned_glossary1     cleaned_glossary2
# 0             1                 postal code  postal index numbers
# 1             1                 postal code              zip code
# 2             1                 postal code              pin code
# 3             0  gender identity expression    sexual orientation
# 4             0                credit score           credit card

# %%
related=data[data['is_related']==1]

# %%
related.shape #427 related pairs
# Out:
# (427, 6)

# %%
related.head()
# Out:
#                       glossary1              glossary2  is_related  \
# 0                   Postal Code  Postal Index numbers            1
# 1                   Postal Code               Zip Code           1
# 2                   Postal Code              PIN code            1
# 3  Gender Identity / Expression     Sexual Orientation           1
# 4                  Credit Score            Credit Card           1
#
#    is_duplicate           cleaned_glossary1      cleaned_glossary2
# 0             1                 postal code  postal index numbers
# 1             1                 postal code               zip code
# 2             1                 postal code              pin code
# 3             0  gender identity expression     sexual orientation
# 4             0                credit score            credit card

# %%
gloss1=list(related['cleaned_glossary1'].apply(lambda x: str(x)))
gloss2=list(related['cleaned_glossary2'].apply(lambda x: str(x)))

# %%
gloss1[:10]
# Out:
# ['postal code',
#  'postal code',
#  'postal code',
#  'gender identity expression',
#  'credit score',
#  'benefits and entitlements data ',
#  'benefits and entitlements data ',
#  'benefits and entitlements data ',
#  'benefits and entitlements data ',
#  'currency ']

# %%
gloss2[:10]
# Out:
# ['postal index numbers ',
#  'zip code',
#  'pin code ',
#  'sexual orientation',
#  'credit card',
#  'benefits ',
#  'entitlements ',
#  'compensation ',
#  'unemployment insurance',
#  'bills']

# %%
#create related pair list
pair=[]
for i in range(len(gloss1)):
    pair_lst=[]
    pair_lst.append(gloss1[i].rstrip())  #.rstrip() remove the space after text
    pair_lst.append(gloss2[i].rstrip())
    pair.append(pair_lst)

# %%
pair[:10]
# Out:
# [['postal code', 'postal index numbers'],
#  ['postal code', 'zip code'],
#  ['postal code', 'pin code'],
#  ['gender identity expression', 'sexual orientation'],
#  ['credit score', 'credit card'],
#  ['benefits and entitlements data', 'benefits'],
#  ['benefits and entitlements data', 'entitlements'],
#  ['benefits and entitlements data', 'compensation'],
#  ['benefits and entitlements data', 'unemployment insurance'],
#  ['currency', 'bills']]

# %%
#convert list to dataframe with boolean values
te=TransactionEncoder()
te_array=te.fit(pair).transform(pair)
df=pd.DataFrame(te_array, columns=te.columns_)

# %%
df.head(10)
# Out:
#    aadhaar india  aba routing number  academic interests  academic records  \
# 0          False               False               False             False
# 1          False               False               False             False
# 2          False               False               False             False
# 3          False               False               False             False
# 4          False               False               False             False
# 5          False               False               False             False
# 6          False               False               False             False
# 7          False               False               False             False
# 8          False               False               False             False
# 9          False               False               False             False
#
#    academic transcripts  access token  account age  account balance  \
# 0                 False         False        False            False
# 1                 False         False        False            False
# 2                 False         False        False            False
# 3                 False         False        False            False
# 4                 False         False        False            False
# 5                 False         False        False            False
# 6                 False         False        False            False
# 7                 False         False        False            False
# 8                 False         False        False            False
# 9                 False         False        False            False
#
#    account information  account number  ...  weight  western astrology  \
# 0                False           False  ...   False              False
# 1                False           False  ...   False              False
# 2                False           False  ...   False              False
# 3                False           False  ...   False              False
# 4                False           False  ...   False              False
# 5                False           False  ...   False              False
# 6                False           False  ...   False              False
# 7                False           False  ...   False              False
# 8                False           False  ...   False              False
# 9                False           False  ...   False              False
#
#    willingness to purchase a good  work measurement  \
# 0                           False             False
# 1                           False             False
# 2                           False             False
# 3                           False             False
# 4                           False             False
# 5                           False             False
# 6                           False             False
# 7                           False             False
# 8                           False             False
# 9                           False             False
#
#    workers compensation claims  workplace policy  written signatures  x pixel  \
# 0                        False             False               False    False
# 1                        False             False               False    False
# 2                        False             False               False    False
# 3                        False             False               False    False
# 4                        False             False               False    False
# 5                        False             False               False    False
# 6                        False             False               False    False
# 7                        False             False               False    False
# 8                        False             False               False    False
# 9                        False             False               False    False
#
#    zip code  zodiac
# 0     False   False
# 1      True   False
# 2     False   False
# 3     False   False
# 4     False   False
# 5     False   False
# 6     False   False
# 7     False   False
# 8     False   False
# 9     False   False
#
# [10 rows x 448 columns]

# %%
#find frequently occurring itemsets using apriory algorithm
from mlxtend.frequent_patterns import apriori
frequent_itemsets_ap = apriori(df, min_support=0.0001, use_colnames=True)

# %%
print(frequent_itemsets_ap)
# Out:
#       support                                           itemsets
# 0    0.004684                                    (aadhaar india)
# 1    0.004684                               (aba routing number)
# 2    0.002342                               (academic interests)
# 3    0.002342                                 (academic records)
# 4    0.009368                             (academic transcripts)
# 5    0.002342                                     (access token)
# 6    0.009368                                      (account age)
# 7    0.004684                                  (account balance)
# 8    0.002342                              (account information)
# 9    0.004684                                   (account number)
# 10   0.009368                                 (account password)
# 11   0.002342                         (account password history)
# 12   0.004684                               (ach routing number)
# 13   0.002342                                (additional salary)
# 14   0.002342                                              (age)
# 15   0.002342                                (age of individual)
# 16   0.002342                                    (age of person)
# 17   0.002342                                  (amount borrowed)
# 18   0.002342                                   (amount payable)
# 19   0.002342                 (amounts paid by the data subject)
# 20   0.002342                                  (annual turnover)
# 21   0.002342                             (app install location)
# 22   0.014052                  (application installed on device)
# 23   0.002342          (archive of transcripts from online chat)
# 24   0.002342                                   (asset workflow)
# 25   0.002342                             (asset workflow stage)
# 26   0.009368                                (astrological sign)
# 27   0.014052                                (audio information)
# 28   0.002342                                      (audio media)
# 29   0.002342                                  (audio recording)
# ..        ...                                                ...
# 841  0.004684         (termination date, reason for termination)
# 842  0.002342  (reason for termination, termination notice pe...
# 843  0.002342             (salary wage expectation, salary wage)
# 844  0.002342                                (tips, salary wage)
# 845  0.002342                    (search history, search record)
# 846  0.002342                   (search records, search history)
# 847  0.002342                    (signature, written signatures)
# 848  0.002342  (sleep stage classification, sleep pattern rec...
# 849  0.002342   (sleep pattern recognition, sleep stage scoring)
# 850  0.002342     (social media account, social media followers)
# 851  0.002342     (social media followers, social media contact)
# 852  0.002342   (social media followers, social media following)
# 853  0.002342     (social media history, social media followers)
# 854  0.002342           (voice recognition, speaker recognition)
# 855  0.002342            (voice recognition, speech recognition)
# 856  0.002342                            (state province, state)
# 857  0.002342                         (state province, zip code)
# 858  0.002342  (thermal information, temperature based screen...
# 859  0.002342         (termination date, termination conditions)
# 860  0.002342      (thermal information, thermal imaging system)
# 861  0.002342           (travel booking details, travel history)
# 862  0.002342                  (vascular pattern, vein patterns)
# 863  0.002342  (vehicle registration, vehicle identification ...
# 864  0.002342               (vehicle identification number, vin)
# 865  0.002342       (vein patterns, vein pattern authentication)
# 866  0.002342                           (vi, visual information)
# 867  0.002342                 (visual media, visual information)
# 868  0.002342  (visual presentation services, visual informat...
# 869  0.002342               (voice recognition, voice recording)
# 870  0.002342                    (voice recognition, voiceprint)
#
# [871 rows x 2 columns]

# %%
#find frequently occurring itemsets using F-P Growth
from mlxtend.frequent_patterns import fpgrowth
frequent_itemsets_fp=fpgrowth(df, min_support=0.0001, use_colnames=True)

# %%
print(frequent_itemsets_fp)
# Out:
#       support                                           itemsets
# 0    0.007026                                      (postal code)
# 1    0.002342                             (postal index numbers)
# 2    0.004684                                         (zip code)
# 3    0.002342                                         (pin code)
# 4    0.007026                       (gender identity expression)
# 5    0.002342                               (sexual orientation)
# 6    0.009368                                     (credit score)
# 7    0.007026                                      (credit card)
# 8    0.009368                   (benefits and entitlements data)
# 9    0.004684                                         (benefits)
# 10   0.002342                                     (entitlements)
# 11   0.007026                                     (compensation)
# 12   0.002342                           (unemployment insurance)
# 13   0.009368                                         (currency)
# 14   0.002342                                            (bills)
# 15   0.002342                                             (cash)
# 16   0.002342                                        (banknotes)
# 17   0.002342                                     (legal tender)
# 18   0.009368                                 (account password)
# 19   0.002342                         (account password history)
# 20   0.004684                             (bonus payment amount)
# 21   0.002342                                (additional salary)
# 22   0.002342                                  (annual turnover)
# 23   0.009368                            (current employer name)
# 24   0.002342                                    (employer name)
# 25   0.007026                          (previous employer names)
# 26   0.007026                                       (pixel tags)
# 27   0.002342                                        (site tags)
# 28   0.002342                                   (tracking pixel)
# 29   0.002342                                          (x pixel)
# ..        ...                                                ...
# 841  0.002342       (vein patterns, vein pattern authentication)
# 842  0.002342                   (aadhaar india, passport number)
# 843  0.002342             (aadhaar india, identification number)
# 844  0.002342  (health safety related information and reporti...
# 845  0.002342  (medical report, health safety related informa...
# 846  0.002342                    (medical report, eating habits)
# 847  0.002342  (health safety related information and reporti...
# 848  0.002342  (health safety related information and reporti...
# 849  0.002342             (bank statements, bank account number)
# 850  0.002342                         (savings, bank statements)
# 851  0.002342                          (income, bank statements)
# 852  0.002342           (academic transcripts, academic records)
# 853  0.002342                (transcripts, academic transcripts)
# 854  0.002342         (academic transcripts, academic interests)
# 855  0.002342  (bullying and harassment details, bullying and...
# 856  0.002342                  (line reporting manager, manager)
# 857  0.002342    (managing organization, line reporting manager)
# 858  0.002342                      (marital status, nationality)
# 859  0.002342                    (marital status, date of birth)
# 860  0.002342                              (marital status, age)
# 861  0.002342           (criminal records, criminal case record)
# 862  0.002342                 (public records, criminal records)
# 863  0.002342           (financial transactions, amount payable)
# 864  0.002342     (awarded credit lines, financial transactions)
# 865  0.002342           (financial transactions, payment method)
# 866  0.002342  (financial transactions, amounts paid by the d...
# 867  0.002342                 (financial transactions, deposits)
# 868  0.002342                                         (id, name)
# 869  0.002342  (bank account number, transfer method to desti...
# 870  0.002342                    (customer survey, created date)
#
# [871 rows x 2 columns]

# %%
#mine the association rules
from mlxtend.frequent_patterns import association_rules
rules_ap = association_rules(frequent_itemsets_ap, metric="confidence", min_threshold=0.1)


rules_fp = association_rules(frequent_itemsets_fp, metric="confidence", min_threshold=0.1)

# %%
print(rules_ap.head(10))
# Out:
#                antecedents              consequents  antecedent support  \
# 0          (aadhaar india)  (identification number)            0.004684
# 1  (identification number)          (aadhaar india)            0.002342
# 2          (aadhaar india)        (passport number)            0.004684
# 3     (aba routing number)     (ach routing number)            0.004684
# 4     (ach routing number)     (aba routing number)            0.004684
# 5     (aba routing number)   (check routing number)            0.004684
# 6   (check routing number)     (aba routing number)            0.002342
# 7   (academic transcripts)     (academic interests)            0.009368
# 8     (academic interests)   (academic transcripts)            0.002342
# 9   (academic transcripts)       (academic records)            0.009368
#
#    consequent support   support  confidence    lift  leverage  conviction
# 0            0.002342  0.002342        0.50  213.50  0.002331    1.995316
# 1            0.004684  0.002342        1.00  213.50  0.002331         inf
# 2            0.023419  0.002342        0.50   21.35  0.002232    1.953162
# 3            0.004684  0.002342        0.50  106.75  0.002320    1.990632
# 4            0.004684  0.002342        0.50  106.75  0.002320    1.990632
# 5            0.002342  0.002342        0.50  213.50  0.002331    1.995316
# 6            0.004684  0.002342        1.00  213.50  0.002331         inf
# 7            0.002342  0.002342        0.25  106.75  0.002320    1.330211
# 8            0.009368  0.002342        1.00  106.75  0.002320         inf
# 9            0.002342  0.002342        0.25  106.75  0.002320    1.330211

# %%
print(rules_fp.head())
# Out:
#               antecedents             consequents  antecedent support  \
# 0           (postal code)  (postal index numbers)            0.007026
# 1  (postal index numbers)           (postal code)            0.002342
# 2           (postal code)              (zip code)            0.007026
# 3              (zip code)           (postal code)            0.004684
# 4        (state province)              (zip code)            0.007026
#
#    consequent support   support  confidence        lift  leverage  conviction
# 0            0.002342  0.002342    0.333333  142.333333  0.002325    1.496487
# 1            0.007026  0.002342    1.000000  142.333333  0.002325         inf
# 2            0.004684  0.002342    0.333333   71.166667  0.002309    1.492974
# 3            0.007026  0.002342    0.500000   71.166667  0.002309    1.985948
# 4            0.004684  0.002342    0.333333   71.166667  0.002309    1.492974

# %%
rules_fp['consequents'][rules_fp.antecedents=='{zip code}']
# Out:
# Series([], Name: consequents, dtype: object)

# %%
df_rules_fp=pd.DataFrame(rules_fp)

# %%
df_rules_fp.head(10)
# Out:
#                     antecedents                   consequents  \
# 0                 (postal code)        (postal index numbers)
# 1        (postal index numbers)                 (postal code)
# 2                 (postal code)                    (zip code)
# 3                    (zip code)                 (postal code)
# 4              (state province)                    (zip code)
# 5                    (zip code)              (state province)
# 6                 (postal code)                    (pin code)
# 7                    (pin code)                 (postal code)
# 8          (sexual orientation)  (gender identity expression)
# 9  (gender identity expression)          (sexual orientation)
#
#    antecedent support  consequent support   support  confidence        lift  \
# 0            0.007026            0.002342  0.002342    0.333333  142.333333
# 1            0.002342            0.007026  0.002342    1.000000  142.333333
# 2            0.007026            0.004684  0.002342    0.333333   71.166667
# 3            0.004684            0.007026  0.002342    0.500000   71.166667
# 4            0.007026            0.004684  0.002342    0.333333   71.166667
# 5            0.004684            0.007026  0.002342    0.500000   71.166667
# 6            0.007026            0.002342  0.002342    0.333333  142.333333
# 7            0.002342            0.007026  0.002342    1.000000  142.333333
# 8            0.002342            0.007026  0.002342    1.000000  142.333333
# 9            0.007026            0.002342  0.002342    0.333333  142.333333
#
#    leverage  conviction
# 0  0.002325    1.496487
# 1  0.002325         inf
# 2  0.002309    1.492974
# 3  0.002309    1.985948
# 4  0.002309    1.492974
# 5  0.002309    1.985948
# 6  0.002325    1.496487
# 7  0.002325         inf
# 8  0.002325         inf
# 9  0.002325    1.496487

# %%
df_rules_fp['antecedents'][0]
# Out:
# frozenset({'postal code'})

# %%
df_rules_fp[df_rules_fp['antecedents']=={'postal code'}]
# Out:
#      antecedents             consequents  antecedent support  \
# 0  (postal code)  (postal index numbers)            0.007026
# 2  (postal code)              (zip code)            0.007026
# 6  (postal code)              (pin code)            0.007026
#
#    consequent support   support  confidence        lift  leverage  conviction
# 0            0.002342  0.002342    0.333333  142.333333  0.002325    1.496487
# 2            0.004684  0.002342    0.333333   71.166667  0.002309    1.492974
# 6            0.002342  0.002342    0.333333  142.333333  0.002325    1.496487

# %%
df_rules_fp[df_rules_fp['antecedents']=={'social security number'}]
# Out:
#                   antecedents                                  consequents  \
# 16   (social security number)                                (credit card)
# 199  (social security number)  (individual taxpayer identification number)
# 203  (social security number)             (national identification number)
# 205  (social security number)                                (nationality)
#
#      antecedent support  consequent support   support  confidence       lift  \
# 16             0.009368            0.007026  0.002342        0.25  35.583333
# 199            0.009368            0.009368  0.002342        0.25  26.687500
# 203            0.009368            0.009368  0.002342        0.25  26.687500
# 205            0.009368            0.018735  0.002342        0.25  13.343750
#
#      leverage  conviction
# 16   0.002276    1.323966
# 199  0.002254    1.320843
# 203  0.002254    1.320843
# 205  0.002166    1.308353

# %%
df_rules_fp[df_rules_fp['antecedents']=={'credit card'}]
# Out:
#        antecedents               consequents  antecedent support  \
# 15   (credit card)            (credit score)            0.007026
# 17   (credit card)  (social security number)            0.007026
# 452  (credit card)         (payment history)            0.007026
#
#      consequent support   support  confidence       lift  leverage  conviction
# 15             0.009368  0.002342    0.333333  35.583333  0.002276    1.485948
# 17             0.009368  0.002342    0.333333  35.583333  0.002276    1.485948
# 452            0.004684  0.002342    0.333333  71.166667  0.002309    1.492974

# %%
df_rules_fp[df_rules_fp['antecedents']=={'bank account information'}]
# Out:
#                     antecedents            consequents  antecedent support  \
# 535  (bank account information)  (bank account number)            0.004684
# 537  (bank account information)       (routing number)            0.004684
#
#      consequent support   support  confidence   lift  leverage  conviction
# 535            0.016393  0.002342         0.5   30.5  0.002265    1.967213
# 537            0.002342  0.002342         0.5  213.5  0.002331    1.995316

# %%
df_rules_fp[df_rules_fp['antecedents']=={'voiceprint'}]
# Out:
#       antecedents          consequents  antecedent support  \
# 304  (voiceprint)  (voice recognition)            0.004684
# 306  (voiceprint)        (fingerprint)            0.004684
#
#      consequent support   support  confidence  lift  leverage  conviction
# 304             0.01171  0.002342         0.5  42.7  0.002287    1.976581
# 306             0.01171  0.002342         0.5  42.7  0.002287    1.976581

# %%
df_rules_fp[df_rules_fp['antecedents']=={'height'}]
# Out:
#     antecedents              consequents  antecedent support  \
# 267    (height)  (physical descriptions)            0.009368
# 269    (height)                 (weight)            0.009368
# 271    (height)      (vertical distance)            0.009368
#
#      consequent support   support  confidence      lift  leverage  conviction
# 267            0.009368  0.002342        0.25   26.6875  0.002254    1.320843
# 269            0.011710  0.004684        0.50   42.7000  0.004574    1.976581
# 271            0.002342  0.002342        0.25  106.7500  0.002320    1.330211

# %%
df_rules_fp[df_rules_fp['antecedents']=={'age'}]
# Out:
#     antecedents       consequents  antecedent support  consequent support  \
# 815       (age)  (marital status)            0.002342            0.009368
#
#       support  confidence    lift  leverage  conviction
# 815  0.002342         1.0  106.75   0.00232         inf

# %%
df_rules_fp[df_rules_fp['antecedents']=={'social security number'}]['consequents']
# Out:
# 16                                   (credit card)
# 199    (individual taxpayer identification number)
# 203               (national identification number)
# 205                                  (nationality)
# Name: consequents, dtype: object

# %%
def display_output(input_term):
    return df_rules_fp[df_rules_fp['antecedents']=={input_term}]['consequents']

# %%
a='social security number'
display_output(a)
# Out:
# 16                                   (credit card)
# 199    (individual taxpayer identification number)
# 203               (national identification number)
# 205                                  (nationality)
# Name: consequents, dtype: object

# %%
a=input()
display_output(a)
# Out:
#  social security number
# 16                                   (credit card)
# 199    (individual taxpayer identification number)
# 203               (national identification number)
# 205                                  (nationality)
# Name: consequents, dtype: object
